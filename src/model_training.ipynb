# %% [markdown]
# # Hyperparameter Fine-Tuning
#
# This notebook performs hyperparameter fine-tuning for the following models:
#
# - **Decision Tree**
# - **Gaussian Naive Bayes**
# - **Logistic Regression (L1 penalty)**
# - **Logistic Regression (L2 penalty)**
# - **Multi-Layer Perceptron (MLP)**
#
# Hyperparameter search will be performed using **Grid Search**. Although it is computationally expensive, it allows exploring a wide range of reasonable hyperparameter values.
#
# We will first process the raw data or load a precomputed TF-IDF encoded dataset if it already exists, and then proceed with hyperparameter optimization.

# %%
from tfidf_extractor import load_and_vectorize, write_to_file, is_valid_csv
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
import os
import pandas as pd
import joblib

# %%
PROCESSED = "../data/processed/"
RAW = "../data/raw/"
RANDOM_STATE = 1
REFIT_METRIC = "f1_macro"
N_JOBS = 4
VERBOSE = 2

# %% [markdown]
# ## Preprocessing and TF-IDF encoding

# %%
raw_files = [
    f"{RAW}train.csv",
    f"{RAW}test.csv",
    f"{RAW}validation.csv"
]

processed_files = [
    f"{PROCESSED}train_features.csv",
    f"{PROCESSED}test_features.csv",
    f"{PROCESSED}validation_features.csv"
]

# %%
# Check if processed files are valid; if not, process raw data
need_preprocessing = not all(is_valid_csv(file) for file in processed_files)

if need_preprocessing:
    print("Processing raw data and extracting TF-IDF features...")
    
    # Check if raw files are valid
    if not all(is_valid_csv(file) for file in raw_files):
        print("ERROR: Raw data files appear to be Git LFS pointers.")
        print("Please run: git lfs pull")
        print("Or download the actual data files manually.")
        raise FileNotFoundError("Raw data files are not available. Please pull from Git LFS.")
    
    X_train, y_train, X_test, y_test, X_val, y_val, vectorizer = load_and_vectorize(
        train_path=raw_files[0],
        test_path=raw_files[1],
        validation_path=raw_files[2]
    )

    # Save processed data
    write_to_file(processed_files[0], X_train, y_train)
    write_to_file(processed_files[1], X_test, y_test)
    write_to_file(processed_files[2], X_val, y_val)
    
    print("TF-IDF feature extraction completed. Files saved.")
else:
    print("Processed files already exist and are valid. Skipping preprocessing.")
# Out:
# Processed files already exist and are valid. Skipping preprocessing.

# %%
# Load processed data
try:
    df_train = pd.read_csv(processed_files[0])
    
    # Verify the data was loaded correctly
    print(f"Training set shape: {df_train.shape}")
    print(f"\nTraining set columns: {df_train.columns.tolist()[:5]}... (showing first 5)")
    print(f"Training set has 'Label' column: {'Label' in df_train.columns}")
    
    if 'Label' not in df_train.columns:
        raise ValueError("'Label' column not found in processed data. Please regenerate the processed files.")
        
except Exception as e:
    print(f"Error loading processed data: {e}")
    print("\nIf you see Git LFS pointer errors, you need to:")
    print("1. Install Git LFS: brew install git-lfs (on macOS) or visit https://git-lfs.github.com/")
    print("2. Initialize Git LFS: git lfs install")
    print("3. Pull the actual files: git lfs pull")
    print("\nAlternatively, run the preprocessing cell above to regenerate the processed files.")
    raise
# Out:
# Training set shape: (50587, 5001)
# Test set shape: (6324, 5001)
# Validation set shape: (6324, 5001)
#
# Training set columns: ['0', '1', '2', '3', '4']... (showing first 5)
# Training set has 'Label' column: True

# %% [markdown]
# ### K-fold cross validation

# %%
# K-fold cross validation on the training set
X = df_train.drop(columns=['Label'])
y = df_train['Label']

n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_STATE)

# %%
X.shape
# Out:
# (50587, 5000)

# %%
scoring = {
    'accuracy': 'accuracy',
    'precision_macro': 'precision_macro',
    'recall_macro': 'recall_macro',
    'f1_macro': 'f1_macro'
}

# %% [markdown]
# ## Hyperparemter tuning

# %% [markdown]
# ### Decision Tree
# To extract the best performance out of the decision tree model we are going to tune the following hyperparameters:
# * `min_sample_split` - minimum number of observations to split a node.
# * `max_depth` - max depth of the tree

# %%
# Optimized grid: removed max_depth=None (very slow with 5000 features)
# Added max_features to speed up splits (only evaluates sqrt of features per split)
param_grid = {
    'max_depth': [10, 20, 30, 50, 100, 1000, 5000],  # Removed None and very deep trees
    'min_samples_split': [2, 5, 10, 20, 50],
    'max_features': ['sqrt', 'log2']  # Limits features evaluated per split (much faster!)
}

grid = GridSearchCV(
    DecisionTreeClassifier(random_state=RANDOM_STATE),
    param_grid=param_grid,
    scoring=scoring,
    refit=REFIT_METRIC,
    cv=kf,
    return_train_score=False,
    n_jobs=N_JOBS,
    verbose=VERBOSE
)

print("Starting Decision Tree grid search (optimized for speed)...")
grid.fit(X, y)
# Out:
# Starting Decision Tree grid search (optimized for speed)...
# Fitting 5 folds for each of 70 candidates, totalling 350 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   5.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=5; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=20; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=50; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=50; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=50; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=50; total time=   1.0s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   0.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   0.6s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2; total time=   0.6s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   0.6s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   0.6s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   0.6s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   0.6s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=20; total time=   0.6s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   0.6s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=20; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   0.9s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2; total time=   0.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=50; total time=   0.9s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2; total time=   0.8s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=20; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   1.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   1.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   0.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=50; total time=   1.0s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   0.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   0.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   0.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2; total time=   0.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   0.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   0.8s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=10; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=30, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2; total time=   1.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2; total time=   1.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2; total time=   1.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2; total time=   1.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2; total time=   1.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5; total time=   1.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5; total time=   1.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5; total time=   1.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5; total time=   1.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5; total time=   1.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=10; total time=   1.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=10; total time=   1.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=10; total time=   1.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=10; total time=   1.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=20; total time=   1.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=10; total time=   1.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=20; total time=   1.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=20; total time=   1.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=20; total time=   1.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=20; total time=   1.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2; total time=   0.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=50; total time=   1.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2; total time=   1.0s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5; total time=   1.0s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=50, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=20; total time=   0.7s
# [CV] END max_depth=50, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=50; total time=   0.7s
# [CV] END max_depth=50, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=50, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2; total time=   1.3s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2; total time=   1.4s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2; total time=   1.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2; total time=   1.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=2; total time=   1.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=5; total time=   1.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=10; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=10; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=10; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=10; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=10; total time=   1.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=20; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=20; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=20; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=20; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=20; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=50; total time=   1.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=50; total time=   1.5s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2; total time=   1.0s
# [CV] END max_depth=100, max_features=sqrt, min_samples_split=50; total time=   1.5s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2; total time=   1.1s
# [CV] END max_depth=100, max_features=log2, min_samples_split=2; total time=   1.0s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5; total time=   1.2s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=100, max_features=log2, min_samples_split=5; total time=   1.1s
# [CV] END max_depth=100, max_features=log2, min_samples_split=10; total time=   1.1s
# [CV] END max_depth=100, max_features=log2, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=100, max_features=log2, min_samples_split=10; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=100, max_features=log2, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=100, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=100, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=2; total time=   1.3s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=2; total time=   1.3s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=2; total time=   1.6s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=2; total time=   1.6s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=5; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=2; total time=   1.6s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=5; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=5; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=5; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=5; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=10; total time=   1.4s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=10; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=10; total time=   1.4s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=10; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=10; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=20; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=20; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=20; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=20; total time=   1.6s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=20; total time=   1.6s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=50; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=50; total time=   1.5s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=2; total time=   1.0s
# [CV] END max_depth=1000, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=2; total time=   0.8s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=2; total time=   0.8s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=2; total time=   1.2s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=5; total time=   1.0s[CV] END max_depth=1000, max_features=log2, min_samples_split=5; total time=   1.0s
#
# [CV] END max_depth=1000, max_features=log2, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=20; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=20; total time=   0.9s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=1000, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=2; total time=   1.3s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=2; total time=   1.3s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=2; total time=   1.5s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=2; total time=   1.5s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=5; total time=   1.5s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=2; total time=   1.6s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=5; total time=   1.6s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=5; total time=   1.6s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=5; total time=   1.4s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=5; total time=   1.4s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=10; total time=   1.5s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=10; total time=   1.5s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=10; total time=   1.6s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=10; total time=   1.6s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=10; total time=   1.5s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=20; total time=   1.5s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=20; total time=   1.4s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=20; total time=   1.5s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=20; total time=   1.4s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=20; total time=   1.4s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=50; total time=   1.5s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=50; total time=   1.5s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=5000, max_features=sqrt, min_samples_split=50; total time=   1.4s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=2; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=2; total time=   1.0s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=2; total time=   1.1s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=5; total time=   0.8s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=5; total time=   1.2s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=10; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=5; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=10; total time=   0.8s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=10; total time=   1.0s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=20; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=20; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=20; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=20; total time=   0.8s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=50; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=50; total time=   0.9s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=50; total time=   0.8s
# [CV] END max_depth=5000, max_features=log2, min_samples_split=50; total time=   0.8s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=DecisionTreeClassifier(random_state=1), n_jobs=4,
#              param_grid={'max_depth': [10, 20, 30, 50, 100, 1000, 5000],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': [2, 5, 10, 20, 50]},
#              refit='f1_macro',
#              scoring={'accuracy': 'accuracy', 'f1_macro': 'f1_macro',
#                       'precision_macro': 'precision_macro',
#                       'recall_macro': 'recall_macro'},
#              verbose=2)

# %% [markdown]
# ### Saving the model

# %%
# Save the best model
os.makedirs("../models", exist_ok=True)
best = grid.best_estimator_
joblib.dump(best, "../models/decision_tree.pkl")
# Out:
# ['../models/decision_tree.pkl']

# %% [markdown]
# ### Gaussian Naive Bayes
# Gaussian Naive Bayes hyperparameters to tune:
# * `var_smoothing` - portion of the largest variance of all features that is added to variances for calculation stability

# %%
param_grid_nb = {
    'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6, 1e-5, 1e-4]
}

grid_nb = GridSearchCV(
    GaussianNB(),
    param_grid=param_grid_nb,
    scoring=scoring,
    refit=REFIT_METRIC,
    cv=kf,
    return_train_score=False,
    n_jobs=N_JOBS,
    verbose=VERBOSE
)

grid_nb.fit(X, y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ................................var_smoothing=1e-09; total time=   4.2s
# [CV] END ................................var_smoothing=1e-09; total time=   4.3s
# [CV] END ................................var_smoothing=1e-09; total time=   4.3s
# [CV] END ................................var_smoothing=1e-09; total time=   4.3s
# [CV] END ................................var_smoothing=1e-09; total time=   3.0s
# [CV] END ................................var_smoothing=1e-08; total time=   3.2s
# [CV] END ................................var_smoothing=1e-08; total time=   3.2s
# [CV] END ................................var_smoothing=1e-08; total time=   3.2s
# [CV] END ................................var_smoothing=1e-08; total time=   2.3s
# [CV] END ................................var_smoothing=1e-07; total time=   2.7s
# [CV] END ................................var_smoothing=1e-08; total time=   2.7s
# [CV] END ................................var_smoothing=1e-07; total time=   2.8s
# [CV] END ................................var_smoothing=1e-07; total time=   2.9s
# [CV] END ................................var_smoothing=1e-07; total time=   2.6s
# [CV] END ................................var_smoothing=1e-07; total time=   2.6s
# [CV] END ................................var_smoothing=1e-06; total time=   2.8s
# [CV] END ................................var_smoothing=1e-06; total time=   2.6s
# [CV] END ................................var_smoothing=1e-06; total time=   2.5s
# [CV] END ................................var_smoothing=1e-06; total time=   2.5s
# [CV] END ................................var_smoothing=1e-06; total time=   3.8s
# [CV] END ................................var_smoothing=1e-05; total time=   2.3s
# [CV] END ................................var_smoothing=1e-05; total time=   2.3s
# [CV] END ................................var_smoothing=1e-05; total time=   2.4s
# [CV] END ................................var_smoothing=1e-05; total time=   2.8s
# [CV] END ................................var_smoothing=1e-05; total time=   2.4s
# [CV] END ...............................var_smoothing=0.0001; total time=   2.5s
# [CV] END ...............................var_smoothing=0.0001; total time=   2.6s
# [CV] END ...............................var_smoothing=0.0001; total time=   2.0s
# [CV] END ...............................var_smoothing=0.0001; total time=   1.9s
# [CV] END ...............................var_smoothing=0.0001; total time=   2.2s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=GaussianNB(), n_jobs=4,
#              param_grid={'var_smoothing': [1e-09, 1e-08, 1e-07, 1e-06, 1e-05,
#                                            0.0001]},
#              refit='f1_macro',
#              scoring={'accuracy': 'accuracy', 'f1_macro': 'f1_macro',
#                       'precision_macro': 'precision_macro',
#                       'recall_macro': 'recall_macro'},
#              verbose=2)

# %% [markdown]
# ### Saving the model

# %%
# Save the best model
os.makedirs("../models", exist_ok=True)
best = grid_nb.best_estimator_
joblib.dump(best, "../models/gaussian_nb.pkl")
# Out:
# ['../models/gaussian_nb.pkl']

# %% [markdown]
# ### Logistic Regression with L2 Regularization
# Logistic Regression L2 hyperparameters to tune:
# * `C` - inverse of regularization strength (smaller values specify stronger regularization)

# %%
param_grid_lr_l2 = {
    'C': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]
}

grid_lr_l2 = GridSearchCV(
    LogisticRegression(penalty='l2', max_iter=1000, random_state=RANDOM_STATE, solver='lbfgs'),
    param_grid=param_grid_lr_l2,
    scoring=scoring,
    refit=REFIT_METRIC,
    cv=kf,
    return_train_score=False,
    n_jobs=N_JOBS,
    verbose=VERBOSE
)

grid_lr_l2.fit(X, y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ............................................C=0.001; total time=   2.9s
# [CV] END ............................................C=0.001; total time=   3.0s
# [CV] END ............................................C=0.001; total time=   3.0s
# [CV] END ............................................C=0.001; total time=   3.1s
# [CV] END ............................................C=0.001; total time=   2.0s
# [CV] END .............................................C=0.01; total time=   2.8s
# [CV] END .............................................C=0.01; total time=   2.9s
# [CV] END .............................................C=0.01; total time=   3.0s
# [CV] END .............................................C=0.01; total time=   2.5s
# [CV] END .............................................C=0.01; total time=   2.3s
# [CV] END ..............................................C=0.1; total time=   2.9s
# [CV] END ..............................................C=0.1; total time=   3.2s
# [CV] END ..............................................C=0.1; total time=   2.7s
# [CV] END ..............................................C=0.1; total time=   2.6s
# [CV] END ..............................................C=0.1; total time=   3.4s
# [CV] END ..............................................C=1.0; total time=   3.3s
# [CV] END ..............................................C=1.0; total time=   3.9s
# [CV] END ..............................................C=1.0; total time=   4.8s
# [CV] END ..............................................C=1.0; total time=   4.8s
# [CV] END ..............................................C=1.0; total time=   5.1s
# [CV] END .............................................C=10.0; total time=   7.0s
# [CV] END .............................................C=10.0; total time=   6.4s
# [CV] END .............................................C=10.0; total time=   8.9s
# [CV] END .............................................C=10.0; total time=   6.5s
# [CV] END .............................................C=10.0; total time=   6.5s
# [CV] END ............................................C=100.0; total time=   6.0s
# [CV] END ............................................C=100.0; total time=   6.9s
# [CV] END ............................................C=100.0; total time=   8.3s
# [CV] END ............................................C=100.0; total time=   6.5s
# [CV] END ............................................C=100.0; total time=   6.4s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=LogisticRegression(max_iter=1000, random_state=1),
#              n_jobs=4, param_grid={'C': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]},
#              refit='f1_macro',
#              scoring={'accuracy': 'accuracy', 'f1_macro': 'f1_macro',
#                       'precision_macro': 'precision_macro',
#                       'recall_macro': 'recall_macro'},
#              verbose=2)

# %% [markdown]
# ### Saving the model

# %%
# Save the best model
os.makedirs("../models", exist_ok=True)
best = grid_lr_l2.best_estimator_
joblib.dump(best, "../models/lr_l2.pkl")
# Out:
# ['../models/lr_l2.pkl']

# %% [markdown]
# ### Logistic Regression with L1 Regularization
# Logistic Regression L1 hyperparameters to tune:
# * `C` - inverse of regularization strength (smaller values specify stronger regularization)

# %%
param_grid_lr_l1 = {
    'C': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]
}

grid_lr_l1 = GridSearchCV(
    LogisticRegression(penalty='l1', max_iter=1000, random_state=RANDOM_STATE, solver='liblinear'),
    param_grid=param_grid_lr_l1,
    scoring=scoring,
    refit=REFIT_METRIC,
    cv=kf,
    return_train_score=False,
    n_jobs=N_JOBS,
    verbose=VERBOSE
)

grid_lr_l1.fit(X, y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# /Users/guilhermejose/Repositories/NTT-DATA-challenge/env/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/guilhermejose/Repositories/NTT-DATA-challenge/env/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/guilhermejose/Repositories/NTT-DATA-challenge/env/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/guilhermejose/Repositories/NTT-DATA-challenge/env/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# [CV] END ............................................C=0.001; total time=   3.1s
# [CV] END ............................................C=0.001; total time=   3.2s
# [CV] END ............................................C=0.001; total time=   3.2s
# [CV] END ............................................C=0.001; total time=   3.2s
# /Users/guilhermejose/Repositories/NTT-DATA-challenge/env/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# [CV] END ............................................C=0.001; total time=   2.2s
# [CV] END .............................................C=0.01; total time=   2.3s
# [CV] END .............................................C=0.01; total time=   2.4s
# [CV] END .............................................C=0.01; total time=   2.4s
# [CV] END .............................................C=0.01; total time=   2.2s
# [CV] END .............................................C=0.01; total time=   2.3s
# [CV] END ..............................................C=0.1; total time=   2.5s
# [CV] END ..............................................C=0.1; total time=   2.5s
# [CV] END ..............................................C=0.1; total time=   2.3s
# [CV] END ..............................................C=0.1; total time=   2.2s
# [CV] END ..............................................C=0.1; total time=   2.3s
# [CV] END ..............................................C=1.0; total time=   2.8s
# [CV] END ..............................................C=1.0; total time=   2.2s
# [CV] END ..............................................C=1.0; total time=   2.0s
# [CV] END ..............................................C=1.0; total time=   2.8s
# [CV] END ..............................................C=1.0; total time=   3.2s
# [CV] END .............................................C=10.0; total time=   3.1s
# [CV] END .............................................C=10.0; total time=   3.5s
# [CV] END .............................................C=10.0; total time=   3.5s
# [CV] END .............................................C=10.0; total time=   3.2s
# [CV] END .............................................C=10.0; total time=   3.9s
# [CV] END ............................................C=100.0; total time=   5.0s
# [CV] END ............................................C=100.0; total time=   5.0s
# [CV] END ............................................C=100.0; total time=   4.6s
# [CV] END ............................................C=100.0; total time=   4.9s
# [CV] END ............................................C=100.0; total time=   4.1s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=LogisticRegression(max_iter=1000, penalty='l1',
#                                           random_state=1, solver='liblinear'),
#              n_jobs=4, param_grid={'C': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]},
#              refit='f1_macro',
#              scoring={'accuracy': 'accuracy', 'f1_macro': 'f1_macro',
#                       'precision_macro': 'precision_macro',
#                       'recall_macro': 'recall_macro'},
#              verbose=2)

# %% [markdown]
# ### Saving the model

# %%
# Save the best model
os.makedirs("../models", exist_ok=True)
best = grid_lr_l1.best_estimator_
joblib.dump(best, "../models/lr_l1.pkl")
# Out:
# ['../models/lr_l1.pkl']

# %% [markdown]
# ### Multi-Layer Perceptron (MLP)
# MLP hyperparameters to tune:
# * `hidden_layer_sizes` - number of neurons in each hidden layer
# * `alpha` - L2 penalty (regularization) parameter
# * `learning_rate_init` - initial learning rate

# %%
param_grid_mlp = {
    'hidden_layer_sizes': [(32,), (64,), (128,), (64, 32), (128, 64)],
    'alpha': [0.0001, 0.001, 0.01, 0.1],
    'learning_rate_init': [0.001, 0.01, 0.1]
}

grid_mlp = GridSearchCV(
    MLPClassifier(max_iter=500, random_state=RANDOM_STATE, early_stopping=True, validation_fraction=0.1),
    param_grid=param_grid_mlp,
    scoring=scoring,
    refit=REFIT_METRIC,
    cv=kf,
    return_train_score=False,
    n_jobs=N_JOBS,
    verbose=VERBOSE
)

grid_mlp.fit(X, y)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  12.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  13.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  14.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  14.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  12.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  11.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  12.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  15.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  11.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  11.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  11.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  14.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  11.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  13.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  17.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  19.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  20.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  19.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  18.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  20.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  20.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  21.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  23.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  17.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  21.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  17.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  19.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  25.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  18.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  25.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  30.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  30.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  31.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  29.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  33.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  31.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  54.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  46.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  26.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time= 1.7min
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time= 1.2min
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  38.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  30.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  26.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  31.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  18.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  18.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  18.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  29.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  18.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  20.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  23.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  18.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  43.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  36.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  20.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  19.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  17.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  21.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  23.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time=  38.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time=  38.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time=  49.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time=  35.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time=  37.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  30.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  41.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time= 1.1min
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  37.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  33.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  58.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  34.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  45.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  32.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  16.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  13.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  31.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  15.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  13.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  13.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  23.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  15.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  21.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  14.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  32.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  23.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  20.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  12.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  18.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  27.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  20.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  19.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  22.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  19.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  21.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  48.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  23.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  26.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  37.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  30.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  19.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  20.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  24.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  35.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  19.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  31.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  31.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  33.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  33.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  31.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  41.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  34.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  36.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  30.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  26.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time= 2.2min
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  30.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  31.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  39.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  19.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  18.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  18.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  28.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  50.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  18.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  18.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  29.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  27.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  27.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  18.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  41.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  19.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  24.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  18.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  25.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time=  39.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time=  34.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time=  46.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time=  43.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time= 1.4min
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  46.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  51.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  30.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  37.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  44.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  28.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  57.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  31.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  15.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  15.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  28.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  15.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  14.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  14.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  16.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time= 1.4min
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  19.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  19.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  17.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  13.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  15.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  27.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  17.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  23.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  25.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  22.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  20.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  18.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  18.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  29.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  59.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  20.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  33.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  22.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  25.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  27.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  21.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  18.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  25.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  24.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  30.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time= 1.2min
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  34.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time= 2.2min
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time= 2.0min
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  38.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time=  38.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time= 2.7min
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time= 1.3min
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time= 1.4min
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time= 1.1min
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  30.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  34.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  18.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  50.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  26.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  17.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time= 2.0min
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  19.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  21.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  19.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  20.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  20.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  25.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  34.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  30.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  23.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  21.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  23.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  39.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time= 1.2min
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time= 1.3min
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time= 1.3min
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time= 1.8min
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  38.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  29.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time= 1.1min
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time= 1.9min
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  29.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  47.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  36.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time= 1.0min
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  54.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time= 1.1min
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  19.9s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  34.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  51.6s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  23.0s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  23.8s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.001; total time=  36.0s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  22.6s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  32.3s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  24.3s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  26.1s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.01; total time=  22.5s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  18.1s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  19.2s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  17.8s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  21.3s
# [CV] END alpha=0.1, hidden_layer_sizes=(32,), learning_rate_init=0.1; total time=  25.8s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  38.9s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  28.7s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  48.3s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  39.2s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.001; total time=  33.6s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  48.5s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time= 1.1min
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  47.9s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  51.5s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  28.8s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.01; total time=  50.5s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  48.6s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  47.4s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  37.5s
# [CV] END alpha=0.1, hidden_layer_sizes=(64,), learning_rate_init=0.1; total time=  44.6s
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  52.6s
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time=  51.2s
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time= 1.4min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time= 1.5min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time= 1.9min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.001; total time= 2.9min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time= 1.3min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time= 1.5min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time= 1.3min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.01; total time= 1.5min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time= 1.2min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time= 1.1min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time= 1.2min
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  34.9s
# [CV] END alpha=0.1, hidden_layer_sizes=(128,), learning_rate_init=0.1; total time=  38.1s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  38.9s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  41.3s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  44.2s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  21.4s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time= 1.3min
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.001; total time=  44.9s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  27.1s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  25.6s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  31.4s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.01; total time=  39.4s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  24.7s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  24.8s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  39.9s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  26.8s
# [CV] END alpha=0.1, hidden_layer_sizes=(64, 32), learning_rate_init=0.1; total time=  35.2s
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time=  50.8s
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time= 1.6min
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time= 1.4min
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time= 1.3min
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  36.9s
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  39.0s
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time= 1.2min
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.001; total time= 1.5min
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  34.3s
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.01; total time=  47.0s
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  34.3s
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  30.6s
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  36.7s
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  56.8s
# [CV] END alpha=0.1, hidden_layer_sizes=(128, 64), learning_rate_init=0.1; total time=  54.7s
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=MLPClassifier(early_stopping=True, max_iter=500,
#                                      random_state=1),
#              n_jobs=4,
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1],
#                          'hidden_layer_sizes': [(32,), (64,), (128,), (64, 32),
#                                                 (128, 64)],
#                          'learning_rate_init': [0.001, 0.01, 0.1]},
#              refit='f1_macro',
#              scoring={'accuracy': 'accuracy', 'f1_macro': 'f1_macro',
#                       'precision_macro': 'precision_macro',
#                       'recall_macro': 'recall_macro'},
#              verbose=2)

# %% [markdown]
# ### Saving the model

# %%
# Save the best model
os.makedirs("../models", exist_ok=True)
best = grid_mlp.best_estimator_
joblib.dump(best, "../models/mlp.pkl")
# Out:
# ['../models/mlp.pkl']
